# %% [markdown]
# # Bare bones analysis example of trisonica mini data
#
# 1. First run to convert your bag file to an hdf5 file
# `python ./bag2hdf5.py FILENAME`
#
# 2. Then run the following example

# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt
import scipy.fftpack
from scipy import signal
import scipy.interpolate
import h5py

# %%
def get_pandas_dataframe_from_uncooperative_hdf5(filename, key='first_key'):
    f = h5py.File(filename,'r')
    all_keys = list(f.keys())
    
    if key == 'first_key':
        print('Dataset contains these keys: ')
        print(all_keys)
        key = all_keys[0]
        print('Using only the first key: ', key)
        
    data = f[key][()]
    dic = {}
    for column_label in data.dtype.fields.keys():
        dic.setdefault(column_label, data[column_label])
    df = pandas.DataFrame(dic)
    return df

# %%
filename = 'data/wind.hdf5'
odorname = 'data/odor.hdf5'

# %%
df = get_pandas_dataframe_from_uncooperative_hdf5(filename)
of = get_pandas_dataframe_from_uncooperative_hdf5(odorname)
df
# Out:
# Dataset contains these keys:
# ['trisonica']
# Using only the first key:  trisonica
# Dataset contains these keys:
# ['analog_output']
# Using only the first key:  analog_output
#        header_seq  header_stamp_secs  header_stamp_nsecs header_frame_id  \
# 0               1         1595957763           698545932             b''
# 1               2         1595957763           723485946             b''
# 2               3         1595957763           748548984             b''
# 3               4         1595957763           773571014             b''
# 4               5         1595957763           799024105             b''
# ...           ...                ...                 ...             ...
# 31975       31976         1595958563            74999094             b''
# 31976       31977         1595958563            99951982             b''
# 31977       31978         1595958563           126135110             b''
# 31978       31979         1595958563           151091098             b''
# 31979       31980         1595958563           176158905             b''
#
#        header_stamp  speed  northsouth  westeast  updown  temperature  \
# 0      1.595958e+09    0.0       -0.33      0.14    0.27    27.049999
# 1      1.595958e+09    0.0       -0.40      0.11    0.29    27.100000
# 2      1.595958e+09    0.0       -0.34      0.13    0.33    27.120001
# 3      1.595958e+09    0.0       -0.33      0.20    0.31    27.459999
# 4      1.595958e+09    0.0       -0.21      0.18    0.33    27.780001
# ...             ...    ...         ...       ...     ...          ...
# 31975  1.595959e+09    0.0        0.30      0.23    0.10    27.670000
# 31976  1.595959e+09    0.0       -0.16      0.71    0.05    27.760000
# 31977  1.595959e+09    0.0       -0.17      0.82    0.07    27.200001
# 31978  1.595959e+09    0.0        0.10      0.50    0.29    26.940001
# 31979  1.595959e+09    0.0       -0.02      0.41    0.39    26.510000
#
#            t_secs    t_nsecs             t
# 0      1595957763  698708735  1.595958e+09
# 1      1595957763  723678105  1.595958e+09
# 2      1595957763  748728556  1.595958e+09
# 3      1595957763  773765069  1.595958e+09
# 4      1595957763  799206213  1.595958e+09
# ...           ...        ...           ...
# 31975  1595958563   75276819  1.595959e+09
# 31976  1595958563  100227651  1.595959e+09
# 31977  1595958563  126656379  1.595959e+09
# 31978  1595958563  151646411  1.595959e+09
# 31979  1595958563  176686410  1.595959e+09
#
# [31980 rows x 13 columns]

# %%
of
# Out:
#                      data      t_secs    t_nsecs             t
# 0       b'0.170870328002'  1595957763  649663705  1.595958e+09
# 1       b'0.171183146304'  1595957763  654564510  1.595958e+09
# 2       b'0.170870328002'  1595957763  664562819  1.595958e+09
# 3       b'0.170870328002'  1595957763  664617371  1.595958e+09
# 4       b'0.170870328002'  1595957763  674436704  1.595958e+09
# ...                   ...         ...        ...           ...
# 159902  b'0.132393676904'  1595958563  159710667  1.595959e+09
# 159903  b'0.132393676904'  1595958563  164688882  1.595959e+09
# 159904  b'0.132393676904'  1595958563  169675507  1.595959e+09
# 159905  b'0.131768040301'  1595958563  174647127  1.595959e+09
# 159906  b'0.132393676904'  1595958563  179607195  1.595959e+09
#
# [159907 rows x 4 columns]

# %%
#converting the data type to float from string (to reduce plot data time)
of.data = of.data.astype(float)
of
# Out:
#             data      t_secs    t_nsecs             t
# 0       0.170870  1595957763  649663705  1.595958e+09
# 1       0.171183  1595957763  654564510  1.595958e+09
# 2       0.170870  1595957763  664562819  1.595958e+09
# 3       0.170870  1595957763  664617371  1.595958e+09
# 4       0.170870  1595957763  674436704  1.595958e+09
# ...          ...         ...        ...           ...
# 159902  0.132394  1595958563  159710667  1.595959e+09
# 159903  0.132394  1595958563  164688882  1.595959e+09
# 159904  0.132394  1595958563  169675507  1.595959e+09
# 159905  0.131768  1595958563  174647127  1.595959e+09
# 159906  0.132394  1595958563  179607195  1.595959e+09
#
# [159907 rows x 4 columns]

# %% [markdown]
# # Plot 3D wind

# %%
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(311)
ax1.plot(df.header_stamp, df.northsouth)
ax1.set_ylabel('northsouth')

ax2 = fig.add_subplot(312)
ax2.plot(df.header_stamp, df.westeast)
ax2.set_ylabel('westeast')

ax3 = fig.add_subplot(313)
ax3.plot(df.header_stamp, df.updown)
ax3.set_ylabel('updown')

ax3.set_xlabel('Time, sec')
# Out:
# Text(0.5, 0, 'Time, sec')

# %%
fig2 = plt.figure()

ox = fig2.add_subplot(111)
ox.plot(of.t, of.data)
ox.set_xlabel('Time')
ox.set_ylabel('Odor')
# Out:
# Text(0, 0.5, 'Odor')

# %% [markdown]
# # Calculate turbulent intensity
# https://www.cfd-online.com/Wiki/Turbulence_intensity

# %%
wind_3d = np.vstack((df.northsouth.values, df.westeast.values, df.updown.values))
mean_wind_3d = np.mean(np.linalg.norm(wind_3d, axis=0))
print('Mean wind speed: ', mean_wind_3d)
# Out:
# Mean wind speed:  1.2634012

# %%
std_wind_3d = np.mean(np.std(wind_3d, axis=1))
print('Standard Deviation of wind speeds: ', std_wind_3d)
# Out:
# Standard Deviation of wind speeds:  0.7223802

# %%
turbulent_intensity = std_wind_3d / mean_wind_3d
print('Turbulent Intensity: ', turbulent_intensity)
# Out:
# Turbulent Intensity:  0.57177424

# %%
df3 = pandas.read_csv("~/data/test_6.csv") #load_GPS_directory_to_pandas('.')
df3
# Out:
#           Unnamed: 0  /analog_output/data  /imu/data/angular_velocity/x  \
# 0       1.595958e+09             0.170870                           NaN
# 1       1.595958e+09             0.171183                           NaN
# 2       1.595958e+09             0.170870                           NaN
# 3       1.595958e+09             0.170870                           NaN
# 4       1.595958e+09             0.170870                           NaN
# ...              ...                  ...                           ...
# 399251  1.595959e+09                  NaN                      0.001968
# 399252  1.595959e+09             0.131768                           NaN
# 399253  1.595959e+09                  NaN                           NaN
# 399254  1.595959e+09                  NaN                      0.003835
# 399255  1.595959e+09             0.132394                           NaN
#
#         /imu/data/angular_velocity/y  /imu/data/angular_velocity/z  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 399251                     -0.001410                      0.003282
# 399252                           NaN                           NaN
# 399253                           NaN                           NaN
# 399254                     -0.000932                      0.006817
# 399255                           NaN                           NaN
#
#         /imu/data/angular_velocity_covariance/0  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                 0.000003
# 399252                                      NaN
# 399253                                      NaN
# 399254                                 0.000003
# 399255                                      NaN
#
#         /imu/data/angular_velocity_covariance/1  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                      0.0
# 399252                                      NaN
# 399253                                      NaN
# 399254                                      0.0
# 399255                                      NaN
#
#         /imu/data/angular_velocity_covariance/2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                      0.0
# 399252                                      NaN
# 399253                                      NaN
# 399254                                      0.0
# 399255                                      NaN
#
#         /imu/data/angular_velocity_covariance/3  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                      0.0
# 399252                                      NaN
# 399253                                      NaN
# 399254                                      0.0
# 399255                                      NaN
#
#         /imu/data/angular_velocity_covariance/4  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
# ...                                         ...  ...
# 399251                                 0.000003  ...
# 399252                                      NaN  ...
# 399253                                      NaN  ...
# 399254                                 0.000003  ...
# 399255                                      NaN  ...
#
#         /ublox_gps/fix_velocity/twist/covariance/6  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                         NaN
# 399252                                         NaN
# 399253                                         NaN
# 399254                                         NaN
# 399255                                         NaN
#
#         /ublox_gps/fix_velocity/twist/covariance/7  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                         NaN
# 399252                                         NaN
# 399253                                         NaN
# 399254                                         NaN
# 399255                                         NaN
#
#         /ublox_gps/fix_velocity/twist/covariance/8  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                         NaN
# 399252                                         NaN
# 399253                                         NaN
# 399254                                         NaN
# 399255                                         NaN
#
#         /ublox_gps/fix_velocity/twist/covariance/9  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                         NaN
# 399252                                         NaN
# 399253                                         NaN
# 399254                                         NaN
# 399255                                         NaN
#
#        /ublox_gps/fix_velocity/twist/twist/angular/x  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                           NaN
# 399252                                           NaN
# 399253                                           NaN
# 399254                                           NaN
# 399255                                           NaN
#
#         /ublox_gps/fix_velocity/twist/twist/angular/y  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 399251                                            NaN
# 399252                                            NaN
# 399253                                            NaN
# 399254                                            NaN
# 399255                                            NaN
#
#         /ublox_gps/fix_velocity/twist/twist/angular/z  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 399251                                            NaN
# 399252                                            NaN
# 399253                                            NaN
# 399254                                            NaN
# 399255                                            NaN
#
#         /ublox_gps/fix_velocity/twist/twist/linear/x  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                           NaN
# 399252                                           NaN
# 399253                                           NaN
# 399254                                           NaN
# 399255                                           NaN
#
#         /ublox_gps/fix_velocity/twist/twist/linear/y  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                           NaN
# 399252                                           NaN
# 399253                                           NaN
# 399254                                           NaN
# 399255                                           NaN
#
#         /ublox_gps/fix_velocity/twist/twist/linear/z
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                           NaN
# 399252                                           NaN
# 399253                                           NaN
# 399254                                           NaN
# 399255                                           NaN
#
# [399256 rows x 117 columns]

# %%
df3.rename(columns={'Unnamed: 0':'t_secs'}, inplace=True)
interpolate_data=df3.interpolate()
interpolate_data.to_hdf('data.h5', key='df3', mode='w')
# Out:
# /home/flybot/anaconda3/envs/FlyDataAnalysis/lib/python3.8/site-packages/pandas/core/generic.py:2431: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['/imu/data/header/frame_id', '/ublox_gps/fix/header/frame_id',
#        '/ublox_gps/fix_velocity/header/frame_id'],
#       dtype='object')]
#
#   pytables.to_hdf(

# %%
df4=pandas.read_hdf('data.h5', 'df3')
df4
# Out:
#               t_secs  /analog_output/data  /imu/data/angular_velocity/x  \
# 0       1.595958e+09             0.170870                           NaN
# 1       1.595958e+09             0.171183                           NaN
# 2       1.595958e+09             0.170870                           NaN
# 3       1.595958e+09             0.170870                           NaN
# 4       1.595958e+09             0.170870                           NaN
# ...              ...                  ...                           ...
# 399251  1.595959e+09             0.132081                      0.001968
# 399252  1.595959e+09             0.131768                      0.002590
# 399253  1.595959e+09             0.131977                      0.003213
# 399254  1.595959e+09             0.132185                      0.003835
# 399255  1.595959e+09             0.132394                      0.003835
#
#         /imu/data/angular_velocity/y  /imu/data/angular_velocity/z  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 399251                     -0.001410                      0.003282
# 399252                     -0.001250                      0.004460
# 399253                     -0.001091                      0.005639
# 399254                     -0.000932                      0.006817
# 399255                     -0.000932                      0.006817
#
#         /imu/data/angular_velocity_covariance/0  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                 0.000003
# 399252                                 0.000003
# 399253                                 0.000003
# 399254                                 0.000003
# 399255                                 0.000003
#
#         /imu/data/angular_velocity_covariance/1  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                      0.0
# 399252                                      0.0
# 399253                                      0.0
# 399254                                      0.0
# 399255                                      0.0
#
#         /imu/data/angular_velocity_covariance/2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                      0.0
# 399252                                      0.0
# 399253                                      0.0
# 399254                                      0.0
# 399255                                      0.0
#
#         /imu/data/angular_velocity_covariance/3  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 399251                                      0.0
# 399252                                      0.0
# 399253                                      0.0
# 399254                                      0.0
# 399255                                      0.0
#
#         /imu/data/angular_velocity_covariance/4  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
# ...                                         ...  ...
# 399251                                 0.000003  ...
# 399252                                 0.000003  ...
# 399253                                 0.000003  ...
# 399254                                 0.000003  ...
# 399255                                 0.000003  ...
#
#         /ublox_gps/fix_velocity/twist/covariance/6  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                         0.0
# 399252                                         0.0
# 399253                                         0.0
# 399254                                         0.0
# 399255                                         0.0
#
#         /ublox_gps/fix_velocity/twist/covariance/7  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                    0.037636
# 399252                                    0.037636
# 399253                                    0.037636
# 399254                                    0.037636
# 399255                                    0.037636
#
#         /ublox_gps/fix_velocity/twist/covariance/8  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                         0.0
# 399252                                         0.0
# 399253                                         0.0
# 399254                                         0.0
# 399255                                         0.0
#
#         /ublox_gps/fix_velocity/twist/covariance/9  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 399251                                         0.0
# 399252                                         0.0
# 399253                                         0.0
# 399254                                         0.0
# 399255                                         0.0
#
#        /ublox_gps/fix_velocity/twist/twist/angular/x  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                           0.0
# 399252                                           0.0
# 399253                                           0.0
# 399254                                           0.0
# 399255                                           0.0
#
#         /ublox_gps/fix_velocity/twist/twist/angular/y  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 399251                                            0.0
# 399252                                            0.0
# 399253                                            0.0
# 399254                                            0.0
# 399255                                            0.0
#
#         /ublox_gps/fix_velocity/twist/twist/angular/z  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 399251                                            0.0
# 399252                                            0.0
# 399253                                            0.0
# 399254                                            0.0
# 399255                                            0.0
#
#         /ublox_gps/fix_velocity/twist/twist/linear/x  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                        -0.008
# 399252                                        -0.008
# 399253                                        -0.008
# 399254                                        -0.008
# 399255                                        -0.008
#
#         /ublox_gps/fix_velocity/twist/twist/linear/y  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                        -0.043
# 399252                                        -0.043
# 399253                                        -0.043
# 399254                                        -0.043
# 399255                                        -0.043
#
#         /ublox_gps/fix_velocity/twist/twist/linear/z
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 399251                                         0.035
# 399252                                         0.035
# 399253                                         0.035
# 399254                                         0.035
# 399255                                         0.035
#
# [399256 rows x 117 columns]
